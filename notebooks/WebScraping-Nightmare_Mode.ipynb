# %% [markdown]
# ### Web Scraping the Ryman Calendar

# %% [markdown]
# In this exercise, your objective is to use BeautifulSoup in order to obtain a dataset of upcoming events at the Ryman. This information is available at https://ryman.com/events/, but you will take the contents of this website and convert it into a pandas DataFrame.
#
# The website splits the events across multiple pages, but start by just working on the first page. Later on in the exercise, you'll take what you've done for the first page and apply it across other pages.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from io import StringIO
import re

# %% [markdown]
# ##### Question 1

# %% [markdown]
# Start by using either the inspector or by viewing the page source. Can you identify a tag that might be helpful for finding the names of all performers? For now, just worry about the headliner and don't worry about the opener. (Eg. For Vince Gill, featuring Wendy Moten, we only care about Vince Gill.) Make use of this to create a list containing just the names of each inductee.

# %% [markdown]
# The div tag with class equal to 'info clearfix' would be a good way to iterate through all event descriptions (date, location, name of show), as long as we skip the first one.
# The h3 tag will be helpful for finding performers.

# %%
# Send get request to the Ryman events URL
URL = 'https://ryman.com/events/'
response = requests.get(URL)

# Convert response to BeautifulSoup object
soup = BeautifulSoup(response.text)

# Iterating through all performers on the first page and storing them in performer_names
all_info = soup.findAll('div', {'class' : 'info clearfix'})[1:]
performers = [info.h3.a.text for info in all_info]

# %% [markdown]
# ##### Question 2

# %% [markdown]
#  Next, try and find a tag that could be used to find the date and time for each show. Extract these into a list. Challenge: Convert these into two lists, one containing the date and the other containing the time. (Eg. split Mar 9, 2023 8:00 PM into Mar 9, 2023 and 8:00 PM.)

# %% [markdown]
# The span tag could be helpful for finding the date and time for each show, although there is a different class for each part of the date.  We could also get all text for each act and use a regex to match the date and time.

# %%
# Getting all text for all acts on the first page 
all_info_text = [info.get_text(separator=' ', strip=True) for info in all_info]

# %%
# Using regex to match the dates and times
datetimes = [re.match(r'\w{3,4}\s\d{1,2}\s-?\s?\d{0,2}\s?,\s\d{4}(\s\d{1,2}:\d{2})?', info).group().replace(' ,',',') for info in all_info_text]

# %%
# Using regex to match just the dates
dates = [re.match(r'\w{3,4}\s\d{1,2}\s-?\s?\d{0,2}\s?,\s\d{4}', info).group().replace(' ,',',') for info in all_info_text]

# %%
# Using regex to match just the times (some acts do not have a time)
times=[]
for item in datetimes:
    time = re.findall(r'\d{1,2}:\d{2}', item)
    if time:
        times.append(time[0])
    else:
        times.append('No time')

# %% [markdown]
# ##### Question 3

# %% [markdown]
# Take the lists you created on parts 1 and 2 and convert them into a pandas DataFrame.

# %%
acts_df = pd.DataFrame({'Performer':performers, 'Date':dates, 'Time':times})
acts_df.head(2)
# Out:
#       Performer             Date     Time
# 0  Ella Langley  Nov 6 - 7, 2025  No time
# 1    Watchhouse      Nov 8, 2025     8:00

# %% [markdown]
# ##### Question 4

# %% [markdown]
# Add to your data frame the opening act for all shows that list an opener.

# %%
openers=[]
for act in all_info:
    opener = act.h4
    if opener:
        openers.append(opener.text.split(maxsplit=1)[1].strip())
    else:
        openers.append('No opener')

acts_df['Opener']=openers
acts_df.head(2)
# Out:
#       Performer             Date     Time  \
# 0  Ella Langley  Nov 6 - 7, 2025  No time
# 1    Watchhouse      Nov 8, 2025     8:00
#
#                                       Opener
# 0  Kaitlin Butts (11/6) and Mae Estes (11/7)
# 1            Sarah Kate Morgan & Leo Shannon

# %% [markdown]
# ##### Question 5

# %% [markdown]
# Now, let's see if we can get the results beyond the first page. For this, you'll need to Web Developer Tools of your browser and navigate to the Network tab. Click the "Load More Events" button and you should see a GET request to the www.ryman.com domain.
#     a. Inspect this request and you should see that it goes to a URL like "https://www.ryman.com/events/events_ajax/24?category=0&venue=0&team=0&exclude=&per_page=12&came_from_page=event-list-page". In your Jupyter notebook, send a get request to this url and inspect the results.
#     b. You should find that the results that you get are HTML, but that they are not exactly formatted in a way that can be parsed. See if you can clean up the results set so that you can extract out the same information as above.
#     c. Create a DataFrame that contains data for the next 60 shows.

# %%
URL = 'https://www.ryman.com/events/events_ajax/24?category=0&venue=0&team=0&exclude=&per_page=12&came_from_page=event-list-page'
response = requests.get(URL)
# Inspecting response.text shows a lot of unnecessary double backslashes, so we will clean those up
response.text
# Out:
# '"<div class=\\"eventItem entry holidays_at_the_ryman featured clearfix\\" data-month=\\"December\\" data-year=\\"2025\\" role=\\"group\\" aria-label=\\"event\\">\\n\\t<div class=\\"thumb\\">\\n\\t\\t<a href=\\"https:\\/\\/www.ryman.com\\/event\\/2025-andrew-peterson\\" id=\\"event_listing_thumb_2025-andrew-peterson\\" title=\\"More Info for Andrew Peterson\\" tabindex=\\"-1\\"><img src=\\"https:\\/\\/images.discovery-prod.axs.com\\/2025\\/06\\/uploadedimage_6855aa3f90d4c.jpg\\" alt=\\"More Info for Andrew Peterson\\"\\/><\\/a>\\t\\t\\n<\\/div>\\t<div class=\\"info clearfix\\">\\n\\t\\t<div class=\\"date\\">\\n\\t<a href=\\"\\/event\\/2025-andrew-peterson\\" tabindex=\\"-1\\" title=\\"More Info\\">\\n\\t<span class=\\"m-date__month\\">Dec <\\/span><span class=\\"m-date__day\\"> 7<\\/span><span class=\\"m-date__separator\\">-<\\/span><span class=\\"m-date__day\\">8<\\/span><span class=\\"m-date__year\\">, 2025<\\/span>\\t\\t<\\/a>\\n<\\/div>\\n\\t\\t\\t<div class=\\"location\\">\\n\\t\\t\\t\\tRyman Auditorium\\t\\t\\t<\\/div>\\n\\t\\t\\t\\n\\t\\n\\t<h3 class=\\"title  \\">\\n\\t\\t<a href=\\"https:\\/\\/www.ryman.com\\/event\\/2025-andrew-peterson\\" title=\\"More Info\\" id=\\"event_listing_title_2025-andrew-peterson\\">Andrew Peterson<\\/a>\\t<\\/h3>\\n\\t\\n<div class=\\"buttons\\">\\n\\t<a href=\\"\\/event\\/2025-andrew-peterson\\" target=\\"_self\\" class=\\"tickets onsalenow \\" title=\\"Get Tickets for Andrew Peterson \\" id=\\"event_listing_button_2025-andrew-peterson\\">Get Tickets<\\/a><a href=\\"https:\\/\\/www.ryman.com\\/event\\/2025-andrew-peterson\\" class=\\"more buttons-hide\\" title=\\"Andrew Peterson More Info\\">More Info<\\/a><\\/div>\\t<\\/div>\\n\\t<div class=\\"extras\\">\\n\\t<\\/div><\\/div>\\n<div class=\\"eventItem entry alt holidays_at_the_ryman featured clearfix\\" data-month=\\"December\\" data-year=\\"2025\\" role=\\"group\\" aria-label=\\"event\\">\\n\\t<div class=\\"thumb\\">\\n\\t\\t<a href=\\"https:\\/\\/www.ryman.com\\/event\\/2025-12-09-sarah-brightman-at-8-pm\\" id=\\"event_listing_thumb_2025-12-09-sarah-brightman-at-8-pm\\" title=\\"More Info for Sarah Brightman\\" tabindex=\\"-1\\"><img src=\\"https:\\/\\/images.discovery-prod.axs.com\\/2025\\/05\\/uploadedimage_6813a6a47f063.jpg\\" alt=\\"More Info for Sarah Brightman\\"\\/><\\/a>\\t\\t\\n<\\/div>\\t<div class=\\"info clearfix\\">\\n\\t\\t<div class=\\"date\\">\\n\\t<a href=\\"\\/event\\/2025-12-09-sarah-brightman-at-8-pm\\" tabindex=\\"-1\\" title=\\"More Info\\">\\n\\t<span class=\\"m-date__singleDate\\"><span class=\\"m-date__month\\">Dec <\\/span><span class=\\"m-date__day\\"> 9<\\/span><span class=\\"m-date__year\\">, 2025<\\/span><span class=\\"m-date__hour\\"> 8:00 PM<\\/span><\\/span>\\t\\t<\\/a>\\n<\\/div>\\n\\t\\t\\t<div class=\\"location\\">\\n\\t\\t\\t\\tRyman Auditorium\\t\\t\\t<\\/div>\\n\\t\\t\\t\\n\\t\\n\\t<h3 class=\\"title  \\">\\n\\t\\t<a href=\\"https:\\/\\/www.ryman.com\\/event\\/2025-12-09-sarah-brightman-at-8-pm\\" title=\\"More Info\\" id=\\"event_listing_title_2025-12-09-sarah-brightman-at-8-pm\\">Sarah Brightman<\\/a>\\t<\\/h3>\\n\\t\\n<div class=\\"buttons\\">\\n\\t<a href=\\"\\/event\\/2025-12-09-sarah-brightman-at-8-pm\\" target=\\"_self\\" class=\\"tickets onsalenow \\" title=\\"Get Tickets for Sarah Brightman \\" id=\\"event_listing_button_2025-12-09-sarah-brightman-at-8-pm\\">Get Tickets<\\/a><a href=\\"https:\\/\\/www.ryman.com\\/event\\/2025-12-09-sarah-brightman-at-8-pm\\" class=\\"more buttons-hide\\" title=\\"Sarah Brightman More Info\\">More Info<\\/a><\\/div>\\t<\\/div>\\n\\t<div class=\\"extras\\">\\n\\t<\\/div><\\/div>\\n<div class=\\"eventItem entry holidays_at_the_ryman featured clearfix\\" data-month=\\"December\\" data-year=\\"2025\\" role=\\"group\\" aria-label=\\"event\\">\\n\\t<div class=\\"thumb\\">\\n\\t\\t<a href=\\"https:\\/\\/www.ryman.com\\/event\\/amy-grant-vince-gill-christmas\\" id=\\"event_listing_thumb_amy-grant-vince-gill-christmas\\" title=\\"More Info for Amy Grant &amp; Vinc ...

# %%
soup = BeautifulSoup(response.text.replace('\\',''))
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <p>
#    "
#   </p>
#   <div aria-label="event" class="eventItem entry holidays_at_the_ryman featured clearfix" data-month="December" data-year="2025" role="group">
#    nt
#    <div class="thumb">
#     ntt
#     <a href="https://www.ryman.com/event/2025-andrew-peterson" id="event_listing_thumb_2025-andrew-peterson" tabindex="-1" title="More Info for Andrew Peterson">
#      <img alt="More Info for Andrew Peterson" src="https://images.discovery-prod.axs.com/2025/06/uploadedimage_6855aa3f90d4c.jpg"/>
#     </a>
#     ttn
#    </div>
#    t
#    <div class="info clearfix">
#     ntt
#     <div class="date">
#      nt
#      <a href="/event/2025-andrew-peterson" tabindex="-1" title="More Info">
#       nt
#       <span class="m-date__month">
#        Dec
#       </span>
#       <span class="m-date__day">
#        7
#       </span>
#       <span class="m-date__separator">
#        -
#       </span>
#       <span class="m-date__day">
#        8
#       </span>
#       <span class="m-date__year">
#        , 2025
#       </span>
#       tt
#      </a>
#      n
#     </div>
#     nttt
#     <div class="location">
#      nttttRyman Auditoriumttt
#     </div>
#     ntttntnt
#     <h3 class="title">
#      ntt
#      <a href="https://www.ryman.com/event/2025-andrew-peterson" id="event_listing_title_2025-andrew-peterson" title="More Info">
#       Andrew Peterson
#      </a>
#      t
#     </h3>
#     ntn
#     <div class="buttons">
#      nt
#      <a class="tickets onsalenow" href="/event/2025-andrew-peterson" id="event_listing_button_2025-andrew-peterson" target="_self" title="Get Tickets for Andrew Peterson ">
#       Get Tickets
#      </a>
#      <a class="more buttons-hide" href="https://www.ryman.com/event/2025-andrew-peterson" title="Andrew Peterson More Info">
#       More Info
#      </a>
#     </div>
#     t
#    </div>
#    nt
#    <div class="extras">
#     nt
#    </div>
#   </div>
#   n
#   <div aria-label="event" class="eventItem entry alt holidays_at_the_ryman featured clearfix" data-month="December" data-year="2025" role="group">
#    nt
#    <div class="thumb">
#     ntt
#     <a href="https://www.ryman.com/event/2025-12-09-sarah-brightman-at-8-pm" id="event_listing_thumb_2025-12-09-sarah-brightman-at-8-pm" tabindex="-1" title="More Info for Sarah Brightman">
#      <img alt="More Info for Sarah Brightman" src="https://images.discovery-prod.axs.com/2025/05/uploadedimage_6813a6a47f063.jpg"/>
#     </a>
#     ttn
#    </div>
#    t
#    <div class="info clearfix">
#     ntt
#     <div class="date">
#      nt
#      <a href="/event/2025-12-09-sarah-brightman-at-8-pm" tabindex="-1" title="More Info">
#       nt
#       <span class="m-date__singleDate">
#        <span class="m-date__month">
#         Dec
#        </span>
#        <span class="m-date__day">
#         9
#        </span>
#        <span class="m-date__year">
#         , 2025
#        </span>
#        <span class="m-date__hour">
#         8:00 PM
#        </span>
#       </span>
#       tt
#      </a>
#      n
#     </div>
#     nttt
#     <div class="location">
#      nttttRyman Auditoriumttt
#     </div>
#     ntttntnt
#     <h3 class="title">
#      ntt
#      <a href="https://www.ryman.com/event/2025-12-09-sarah-brightman-at-8-pm" id="event_listing_title_2025-12-09-sarah-brightman-at-8-pm" title="More Info">
#       Sarah Brightman
#      </a>
#      t
#     </h3>
#     ntn
#     <div class="buttons">
#      nt
#      <a class="tickets onsalenow" href="/event/2025-12-09-sarah-brightman-at-8-pm" id="event_listing_button_2025-12-09-sarah-brightman-at-8-pm" target="_self" title="Get Tickets for Sarah Brightman ">
#       Get Tickets
#      </a>
#      <a class="more buttons-hide" href="https://www.ryman.com/event/2025-12-09-sarah-brightman-at-8-pm" title="Sarah Brightman More Info">
#       More Info
#      </a>
#     </div>
#     t
#    </div>
#    nt
#    <div class="extras">
#     nt
#    </div>
#   </div>
#   n
#   <div aria-label="event" class="eventItem entry holidays_at_the_ryman featured clearfix" data-month="December" data-year="2025" role="group">
#    nt
#    <div class="thumb">
#     ntt
#     <a href="https://www.ryman.com/event/amy-grant-vince-gill-christmas" id="event_listing_thumb_amy-grant-vince-gill-christmas" tabindex="-1" title="More Info for Amy Grant &amp; Vince Gill Christmas at the Ryman">
#      <img alt="More Info for Amy Grant &amp; Vince Gill Christmas at the Ryman" src="https://images.discovery-prod.axs.com/2025/04/uploadedimage_67ee8e819b2e2.jpg"/>
#     </a>
#     ttn
#    </div>
#    t
#    <div class="info clearfix">
#     ntt
#     <div class="date">
#      nt
#      <a href="/event/amy-grant-vince-gill-christmas" tabindex="-1" title="More Info">
#       nt
#       <span class="m-date__month">
#        Dec
#       </span>
#       <span class="m-date__day">
#        10
#       </span>
#       <span class="m-date__separator">
#        -
#       </span>
#       <span class="m-date__day">
#        20
#       </span>
#       <span class="m-date__year">
#        , 2025
#       </span>
#       tt
#      </a>
#      n
#     </div>
#     nttt
#     <div class="location">
#      nttttRyman Auditoriumttt
#     </div>
#     ntttntnt
#     <h3 class="title long_title">
#      ntt
#      <a href="https://www.ryman.com/event/amy-grant-vince-gill-christmas" id="event_listing_title_amy-grant-vince-gill-christmas" title="More Info">
#       Amy Grant &amp; Vince Gill Christmas at the Ryman
#      </a>
#      t
#     </h3>
#     ntn
#     <div class="buttons">
#      nt
#      <a class="tickets onsalenow" href="/event/amy-grant-vince-gill-christmas" id="event_listing_button_amy-grant-vince-gill-christmas" target="_self" title="Get Tickets for Amy Grant &amp; Vince Gill Christmas at the Ryman ">
#       Get Tickets
#      </a>
#      <a class="more buttons-hide" href="https://www.ryman.com/event/amy-grant-vince-gill-christmas" title="Amy Grant &amp; Vince Gill Christmas at the Ryman More Info">
#       More Info
#      </a>
#     </div>
#     t
#    </div>
#    nt
#    <div class="extras">
#     nt
#    </div>
#   </div>
#   n
#   <div aria-label="event" class="eventItem entry alt holidays_at_the_ryman featured clearfix" data-month="December" data-year="2025" role="group">
#    nt
#    <div class="thumb">
#     ntt
#     <a href="https://www.ryman.com/event/2025-12-12-leann-rimes-at-8-pm" id="event_listing_thumb_2025-12-12-leann-rimes-at-8-pm" tabindex="-1" title="More Info for LeAnn Rimes">
#      <img alt="More Info for LeAnn Rimes" src="https://images.discovery-prod.axs.com/2025/07/uploadedimage_6878f961db6b3.jpg"/>
#     </a>
#     ttn
#    </div>
#    t
#    <div class="info clearfix">
#     ntt
#     <div class="date">
#      nt
#      <a href="/event/2025-12-12-leann-rimes-at-8-pm" tabindex="-1" title="More Info">
#       nt
#       <span class="m-date__singleDate">
#        <span class="m-date__month">
#         Dec
#        </span>
#        <span class="m-date__day">
#         12
#        </span>
#        <span class="m-date__year">
#         , 2025
#        </span>
#        <span class="m-date__hour">
#         8:00 PM
#        </span>
#       </span>
#       tt
#      </a>
#      n
#     </div>
#     nttt
#     <div class="location">
#      nttttRyman Auditoriumttt
#     </div>
#     ntttntnt
#     <h3 class="title">
#      ntt
#      <a href="https://www.ryman.com/event/2025-12-12-leann-rimes-at-8-pm" id="event_listing_title_2025-12-12-leann-rimes-at-8-pm" title="More Info">
#       LeAnn Rimes
#      </a>
#      t
#     </h3>
#     ntn
#     <div class="buttons">
#      nt
#      <a class="tickets onsalenow" href="/event/2025-12-12-leann-rimes-at-8-pm" id="event_listing_button_2025-12-12-leann-rimes-at-8-pm" target="_self" title="Get Tickets for LeAnn Rimes ">
#       Get Tickets
#      </a>
#      <a class="more buttons-hide" href="https://www.ryman.com/event/2025-12-12-leann-rimes-at-8-pm" title="LeAnn Rimes More Info">
#       More Info
#      </a>
#     </div>
#     t
#    </div>
#    nt
#    <div class="extras">
#     nt
#    </div>
#   </div>
#   n
#   <div aria-label="event" class="eventItem entry holidays_at_the_ryman live_at_the_opry_house clearfix" data-month="December" data-year="2025" role="group">
#    nt
#    <div class="thumb">
#     ntt
#     <a href="https://www.ryman.com/event/2025-for-king-and-country" id="event_listing_thumb_2025-for-king-and-country" tabindex="-1" title="More Info for for KING + COUNTRY">
#      <img alt="More Info for for KING + COUNTRY" src="https://www.ryman.com/assets/img/fKC_678x399_OHLogo-09ae30ddbd.jpg"/>
#     </a>
#     ttn
#    </div>
#    t
#    <div class="info clearfix">
#     ntt
#     <div class="date">
#      nt
#      <a href="/event/2025-for-king-and-country" tabindex="-1" title="More Info">
#       nt
#       <span class="m-date__month">
#        Dec
#       </span>
#       <span class="m-date__day">
#        15
#       </span>
#       <span class="m-date__separator">
#        -
#       </span>
#       <span class="m-date__day">
#        19
#       </span>
#       <span class="m-date__year">
#        , 2025
#       </span>
#       tt
#      </a>
#      n
#     </div>
#     nttt
#     <div class="location">
#      nttttOpry Housettt
#     </div>
#     ntttntnt
#     <h3 class="title title-withTagline">
#      ntt
#      <a href="https://www.ryman.com/event/2025-for-king-and-country" id="event_listing_title_2025-for-king-and-country" title="More Info">
#       for KING + COUNTRY
#      </a>
#      t
#     </h3>
#     nttt
#     <h4 class="tagline">
#      n            A DRUMMER BOY CHRISTMAS: THE LIVE EXPERIENCEtt
#     </h4>
#     n    n
#     <div class="buttons">
#      nt
#      <a class="tickets onsalenow" href="/event/2025-for-king-and-country" id="event_listing_button_2025-for-king-and-country" target="_self" title="Get Tickets for for KING + COUNTRY ">
#       Get Tickets
#      </a>
#      <a class="more buttons-hide" href="https://www.ryman.com/event/2025-for-king-and-country" title="for KING + COUNTRY More Info">
#       More Info
#      </a>
#     </div>
#     t
#    </div>
#    nt
#    <div class="extras">
#     nt
#    </div>
#   </div>
#   n
#   <div aria-label="event" class="eventItem entry alt holidays_at_the_ryman featured clearfix" data-month="December" data-year="2025" role="group">
#    nt
#    <div class="thumb">
#     ntt
#     <a href="https://www.ryman.com/event/2025-12-15-a-prairie-home-companion-christmas-at-7-30-pm" id="event_listing_thumb_2025-12-15-a-prairie-home-companion-christmas-at-7-30-pm" tabindex="-1" title="More Info for A Prairie Home Companion Christmas">
#      <img alt="More Info for A Prairie Home Companion Christmas" src="https://images.discovery-prod.axs.com/2025/07/uploadedimage_687a52aa09045.jpg"/>
#     </a>
#     ttn
#    </div>
#    t
#    <div class="info clearfix">
#     ntt
#     <div class="date">
#      nt
#      <a href="/event/2025-12-15-a-prairie-home-companion-christmas-at-7-30-pm" tabindex="-1" title="More Info">
#       nt
#       <span class="m-date__singleDate">
#        <span class="m-date__month">
#         Dec
#        </span>
#        <span class="m-date__day">
#         15
#        </span>
#        <span class="m-date__year">
#         , 2025
#        </span>
#        <span class="m-date__hour">
#         7:30 PM
#        </span>
#       </span>
#       tt
#      </a>
#      n
#     </div>
#     nttt
#     <div class="location">
#      nttttRyman Auditoriumttt
#     </div>
#     ntttntnt
#     <h3 class="title long_title">
#      ntt
#      <a href="https://www.ryman.com/event/2025-12-15-a-prairie-home-companion-christmas-at-7-30-pm" id="event_listing_title_2025-12-15-a-prairie-home-companion-christmas-at-7-30-pm" title="More Info">
#       A Prairie Home Companion Christmas
#      </a>
#      t
#     </h3>
#     ntn
#     <div class="buttons">
#      nt
#      <a class="tickets onsalenow" href="/event/2025-12-15-a-prairie-home-companion-christmas-at-7-30-pm" id="event_listing_button_2025-12-15-a-prairie-home-companion-christmas-at-7-30-pm" target="_self" title="Get Tickets for A Prairie Home Companion Christmas ">
#       Get Tickets
#      </a>
#      <a class="more buttons-hide" href="https://www.ryman.com/event/2025-12-15-a-prairie-home-companion-christmas-at-7-30-pm" title="A Prairie Home Companion Christmas More Info">
#       More Info
#      </a>
#     </div>
#     t
#    </div>
#    nt
#    <div class="extras">
#     nt
#    </div>
#   </div>
#   n
#   <div aria-label="event" class="eventItem entry featured clearfix" data-month="December" data-year="2025" role="group">
#    nt
#    <div class="thumb">
#     ntt
#     <a href="https://www.ryman.com/event/2025-12-18-kip-moore-at-7-30-pm" id="event_listing_thumb_2025-12-18-kip-moore-at-7-30-pm" tabindex="-1" title="More Info for Kip Moore">
#      <img alt="More Info for Kip Moore" src="https://images.discovery-prod.axs.com/2025/06/uploadedimage_685953e2bc587.jpg"/>
#     </a>
#     ttn
#    </div>
#    t
#    <div class="info clearfix">
#     ntt
#     <div class="date">
#      nt
#      <a href="/event/2025-12-18-kip-moore-at-7-30-pm" tabindex="-1" title="More Info">
#       nt
#       <span class="m-date__singleDate">
#        <span class="m-date__month">
#         Dec
#        </span>
#        <span class="m-date__day">
#         18
#        </span>
#        <span class="m-date__year">
#         , 2025
#        </span>
#        <span class="m-date__hour">
#         7:30 PM
#        </span>
#       </span>
#       tt
#      </a>
#      n
#     </div>
#     nttt
#     <div class="location">
#      nttttRyman Auditoriumttt
#     </div>
#     ntttntnt
#     <h3 class="title title-withTagline">
#      ntt
#      <a href="https://www.ryman.com/event/2025-12-18-kip-moore-at-7-30-pm" id="event_listing_title_2025-12-18-kip-moore-at-7-30-pm" title="More Info">
#       Kip Moore
#      </a>
#      t
#     </h3>
#     nttt
#     <h4 class="tagline">
#      n            with McCoy Moorett
#     </h4>
#     n    n
#     <div class="buttons">
#      nt
#      <a class="tickets onsalenow" href="/event/2025-12-18-kip-moore-at-7-30-pm" id="event_listing_button_2025-12-18-kip-moore-at-7-30-pm" target="_self" title="Get Tickets for Kip Moore ">
#       Get Tickets
#      </a>
#      <a class="more buttons-hide" href="https://www.ryman.com/event/2025-12-18-kip-moore-at-7-30-pm" title="Kip Moore More Info">
#       More Info
#      </a>
#     </div>
#     t
#    </div>
#    nt
#    <div class="extras">
#     nt
#    </div>
#   </div>
#   n
#   <div aria-label="event" class="eventItem entry alt holidays_at_the_ryman featured clearfix" data-month="December" data-year="2025" role="group">
#    nt
#    <div class="thumb">
#     ntt
#     <a href="https://www.ryman.com/event/2025-lady-a-christmas" id="event_listing_thumb_2025-lady-a-christmas" tabindex="-1" title="More Info for Lady A">
#      <img alt="More Info for Lady A" src="https://images.discovery-prod.axs.com/2025/07/uploadedimage_68669852a2eb1.jpg"/>
#     </a>
#     ttn
#    </div>
#    t
#    <div class="info clearfix">
#     ntt
#     <div class="date">
#      nt
#      <a href="/event/2025-lady-a-christmas" tabindex="-1" title="More Info">
#       nt
#       <span class="m-date__month">
#        Dec
#       </span>
#       <span class="m-date__day">
#        21
#       </span>
#       <span class="m-date__separator">
#        -
#       </span>
#       <span class="m-date__day">
#        23
#       </span>
#       <span class="m-date__year">
#        , 2025
#       </span>
#       tt
#      </a>
#      n
#     </div>
#     nttt
#     <div class="location">
#      nttttRyman Auditoriumttt
#     </div>
#     ntttntnt
#     <h3 class="title">
#      ntt
#      <a href="https://www.ryman.com/event/2025-lady-a-christmas" id="event_listing_title_2025-lady-a-christmas" title="More Info">
#       Lady A
#      </a>
#      t
#     </h3>
#     ntn
#     <div class="buttons">
#      nt
#      <a class="tickets onsalenow" href="/event/2025-lady-a-christmas" id="event_listing_button_2025-lady-a-christmas" target="_self" title="Get Tickets for Lady A ">
#       Get Tickets
#      </a>
#      <a class="more buttons-hide" href="https://www.ryman.com/event/2025-lady-a-christmas" title="Lady A More Info">
#       More Info
#      </a>
#     </div>
#     t
#    </div>
#    nt
#    <div class="extras">
#     nt
#    </div>
#   </div>
#   n
#   <div aria-label="event" class="eventItem entry featured clearfix" data-month="December" data-year="2025" role="group">
#    nt
#    <div class="thumb">
#     ntt
#     <a href="https://www.ryman.com/event/2025-matt-mathews" id="event_listing_thumb_2025-matt-mathews" tabindex="-1" title="More Info for Matt Mathews">
#      <img alt="More Info for Matt Mathews" src="https://images.discovery-prod.axs.com/2025/04/uploadedimage_681136f698fa1.jpg"/>
#     </a>
#     ttn
#    </div>
#    t
#    <div class="info clearfix">
#     ntt
#     <div class="date">
#      nt
#      <a href="/event/2025-matt-mathews" tabindex="-1" title="More Info">
#       ntSaturday, December 27 at 5 &amp; 8 PMtt
#      </a>
#      n
#     </div>
#     nttt
#     <div class="location">
#      nttttRyman Auditoriumttt
#     </div>
#     ntttntnt
#     <h3 class="title">
#      ntt
#      <a href="https://www.ryman.com/event/2025-matt-mathews" id="event_listing_title_2025-matt-mathews" title="More Info">
#       Matt Mathews
#      </a>
#      t
#     </h3>
#     ntn
#     <div class="buttons">
#      nt
#      <a class="tickets onsalenow" href="/event/2025-matt-mathews" id="event_listing_button_2025-matt-mathews" target="_self" title="Get Tickets for Matt Mathews ">
#       Get Tickets
#      </a>
#      <a class="more buttons-hide" href="https://www.ryman.com/event/2025-matt-mathews" title="Matt Mathews More Info">
#       More Info
#      </a>
#     </div>
#     t
#    </div>
#    nt
#    <div class="extras">
#     nt
#    </div>
#   </div>
#   n
#   <div aria-label="event" class="eventItem entry alt holidays_at_the_ryman featured clearfix" data-month="December" data-year="2025" role="group">
#    nt
#    <div class="thumb">
#     ntt
#     <a href="https://www.ryman.com/event/2025-12-28-a-drag-queen-christmas-at-7-30-pm" id="event_listing_thumb_2025-12-28-a-drag-queen-christmas-at-7-30-pm" tabindex="-1" title="More Info for A Drag Queen Christmas">
#      <img alt="More Info for A Drag Queen Christmas" src="https://images.discovery-prod.axs.com/2025/07/uploadedimage_68840eb55515f.jpg"/>
#     </a>
#     ttn
#    </div>
#    t
#    <div class="info clearfix">
#     ntt
#     <div class="date">
#      nt
#      <a href="/event/2025-12-28-a-drag-queen-christmas-at-7-30-pm" tabindex="-1" title="More Info">
#       nt
#       <span class="m-date__singleDate">
#        <span class="m-date__month">
#         Dec
#        </span>
#        <span class="m-date__day">
#         28
#        </span>
#        <span class="m-date__year">
#         , 2025
#        </span>
#        <span class="m-date__hour">
#         7:30 PM
#        </span>
#       </span>
#       tt
#      </a>
#      n
#     </div>
#     nttt
#     <div class="location">
#      nttttRyman Auditoriumttt
#     </div>
#     ntttntnt
#     <h3 class="title">
#      ntt
#      <a href="https://www.ryman.com/event/2025-12-28-a-drag-queen-christmas-at-7-30-pm" id="event_listing_title_2025-12-28-a-drag-queen-christmas-at-7-30-pm" title="More Info">
#       A Drag Queen Christmas
#      </a>
#      t
#     </h3>
#     ntn
#     <div class="buttons">
#      nt
#      <a class="tickets onsalenow" href="/event/2025-12-28-a-drag-queen-christmas-at-7-30-pm" id="event_listing_button_2025-12-28-a-drag-queen-christmas-at-7-30-pm" target="_self" title="Get Tickets for A Drag Queen Christmas ">
#       Get Tickets
#      </a>
#      <a class="more buttons-hide" href="https://www.ryman.com/event/2025-12-28-a-drag-queen-christmas-at-7-30-pm" title="A Drag Queen Christmas More Info">
#       More Info
#      </a>
#     </div>
#     t
#    </div>
#    nt
#    <div class="extras">
#     nt
#    </div>
#   </div>
#   n
#   <div aria-label="event" class="eventItem entry holidays_at_the_ryman featured clearfix" data-month="December" data-year="2025" role="group">
#    nt
#    <div class="thumb">
#     ntt
#     <a href="https://www.ryman.com/event/2025-old-crow-medicine-show" id="event_listing_thumb_2025-old-crow-medicine-show" tabindex="-1" title="More Info for Old Crow Medicine Show">
#      <img alt="More Info for Old Crow Medicine Show" src="https://images.discovery-prod.axs.com/2025/02/uploadedimage_67be3fb0a5905.jpg"/>
#     </a>
#     ttn
#    </div>
#    t
#    <div class="info clearfix">
#     ntt
#     <div class="date">
#      nt
#      <a href="/event/2025-old-crow-medicine-show" tabindex="-1" title="More Info">
#       nt
#       <span class="m-date__month">
#        Dec
#       </span>
#       <span class="m-date__day">
#        30
#       </span>
#       <span class="m-date__separator">
#        -
#       </span>
#       <span class="m-date__day">
#        31
#       </span>
#       <span class="m-date__year">
#        , 2025
#       </span>
#       tt
#      </a>
#      n
#     </div>
#     nttt
#     <div class="location">
#      nttttRyman Auditoriumttt
#     </div>
#     ntttntnt
#     <h3 class="title title-withTagline">
#      ntt
#      <a href="https://www.ryman.com/event/2025-old-crow-medicine-show" id="event_listing_title_2025-old-crow-medicine-show" title="More Info">
#       Old Crow Medicine Show
#      </a>
#      t
#     </h3>
#     nttt
#     <h4 class="tagline">
#      n            with The 502s and AJ Lee &amp; Blue Summit and (12/30) and Shovel &amp; Rope and The Creekers (12/31)tt
#     </h4>
#     n    n
#     <div class="buttons">
#      nt
#      <a class="tickets onsalenow" href="/event/2025-old-crow-medicine-show" id="event_listing_button_2025-old-crow-medicine-show" target="_self" title="Get Tickets for Old Crow Medicine Show ">
#       Get Tickets
#      </a>
#      <a class="more buttons-hide" href="https://www.ryman.com/event/2025-old-crow-medicine-show" title="Old Crow Medicine Show More Info">
#       More Info
#      </a>
#     </div>
#     t
#    </div>
#    nt
#    <div class="extras">
#     nt
#    </div>
#   </div>
#   n
#   <div aria-label="event" class="eventItem entry alt opry_at_the_ryman clearfix" data-month="January" data-year="2026" role="group">
#    nt
#    <div class="thumb">
#     ntt
#     <a href="https://www.ryman.com/event/2026-01-02-opry-at-the-ryman-opry-100-at-7-pm" id="event_listing_thumb_2026-01-02-opry-at-the-ryman-opry-100-at-7-pm" tabindex="-1" title="More Info for Opry at the Ryman: OPRY 100">
#      <img alt="More Info for Opry at the Ryman: OPRY 100" src="https://images.discovery-prod.axs.com/2025/07/uploadedimage_6883a335dc007.jpg"/>
#     </a>
#     ttn
#    </div>
#    t
#    <div class="info clearfix">
#     ntt
#     <div class="date">
#      nt
#      <a href="/event/2026-01-02-opry-at-the-ryman-opry-100-at-7-pm" tabindex="-1" title="More Info">
#       nt
#       <span class="m-date__singleDate">
#        <span class="m-date__month">
#         Jan
#        </span>
#        <span class="m-date__day">
#         2
#        </span>
#        <span class="m-date__year">
#         , 2026
#        </span>
#        <span class="m-date__hour">
#         7:00 PM
#        </span>
#       </span>
#       tt
#      </a>
#      n
#     </div>
#     nttt
#     <div class="location">
#      nttttRyman Auditoriumttt
#     </div>
#     ntttntnt
#     <h3 class="title title-withTagline">
#      ntt
#      <a href="https://www.ryman.com/event/2026-01-02-opry-at-the-ryman-opry-100-at-7-pm" id="event_listing_title_2026-01-02-opry-at-the-ryman-opry-100-at-7-pm" title="More Info">
#       Opry at the Ryman: OPRY 100
#      </a>
#      t
#     </h3>
#     nttt
#     <h4 class="tagline">
#      n            Featuring Joe Mullins &amp; The Radio Ramblers, more to be announced...tt
#     </h4>
#     n    n
#     <div class="buttons">
#      nt
#      <a class="tickets onsalenow" href="/event/2026-01-02-opry-at-the-ryman-opry-100-at-7-pm" id="event_listing_button_2026-01-02-opry-at-the-ryman-opry-100-at-7-pm" target="_self" title="Get Tickets for Opry at the Ryman: OPRY 100 ">
#       Get Tickets
#      </a>
#      <a class="more buttons-hide" href="https://www.ryman.com/event/2026-01-02-opry-at-the-ryman-opry-100-at-7-pm" title="Opry at the Ryman: OPRY 100 More Info">
#       More Info
#      </a>
#     </div>
#     t
#    </div>
#    nt
#    <div class="extras">
#     nt
#    </div>
#   </div>
#   n"
#  </body>
# </html>

# %%
# Creating a DataFrame that contains data for the next 60 shows
num_shows=60
URL = f'https://www.ryman.com/events/events_ajax/24?category=0&venue=0&team=0&exclude=&per_page={num_shows}&came_from_page=event-list-page'
response = requests.get(URL)
soup = BeautifulSoup(response.text.replace('\\',''))

all_info = soup.findAll('div', {'class' : 'info clearfix'})[1:]
performers = [info.h3.a.text for info in all_info]

all_info_text = [info.get_text(separator=' ', strip=True) for info in all_info]
#all_info_text[0]
dates = [re.match(r'nt\s(.*?)\stt', info).group() for info in all_info_text[0]]
dates
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[131], line 12
#      10 all_info_text = [info.get_text(separator=' ', strip=True) for info in all_info]
#      11 #all_info_text[0]
# ---> 12 dates = [re.match(r'nt\s{5,25}\stt', info).group() for info in all_info_text[0]]
#      13 dates
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
times=[]
for item in datetimes:
    time = re.findall(r'\d{1,2}:\d{2}', item)
    if time:
        times.append(time[0])
    else:
        times.append('No time')

openers=[]
for act in all_info:
    opener = act.h4
    if opener:
        openers.append(opener.text.split(maxsplit=1)[1].strip())
    else:
        openers.append('No opener')

more_acts_df = pd.DataFrame({'Performer':performers, 'Date':dates, 'Time':times, 'Opener':openers})

more_acts_df
